# %% [markdown]
# # Types of Modules

# %% [markdown]
# ### 1. User Defined Modules
#     The modules that are provided by the user by defining in the program.
# ### 2. Built in Modules
#     The module
