# %% [markdown]
# ### Module :
# - A module if .py file and it consists of variables, functions, and classes.
# - Can use the one module code in some another modle by importing the module.

# %%
print(220 - 105)
# Out:
# 115

# %%
# swapCase using ASCII values.
s = input()
res = ""
for i in s:
    if ord(i) >= 65 and ord(i) <=90:
        res += i.lower()
    else:
        res += i.upper()
print(res)
# Out:
#  caTheTitle
# CAtHEtITLE

# %%
print(chr(90))
# Out:
# Z
